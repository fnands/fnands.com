# %% [markdown]
# ---
# layout: post
# title: Stereo matching through the lens of representation learning
# categories: [stereo]
# date: "2026-03-31"
# author: "Ferdinand Schenck"
# draft: false
# description: .
# ---
